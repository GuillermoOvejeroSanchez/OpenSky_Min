# %%
import pandas as pd

# %%
aircraft = pd.read_csv("data/aircraftDatabase-2021-05.csv")

# %%
aircraft.head()
# Out:
#    icao24 registration manufacturericao               manufacturername  \
# 0     NaN          NaN              NaN                            NaN
# 1  aa3487        N757F              NaN      Raytheon Aircraft Company
# 2  ae267b         6533           VOUGHT                   Aerospatiale
# 3  a4fa61        N42MH              NaN                          Piper
# 4  c04101       C-FYQA              NaN  Champion Aircraft Corporation
#
#              model typecode serialnumber linenumber icaoaircrafttype operator  \
# 0              NaN      NaN          NaN        NaN              NaN      NaN
# 1              A36      NaN       E-3121        NaN              NaN      NaN
# 2   MH-65C Dolphin     AS65         6182        NaN              H2T      NaN
# 3        PA-31-350      NaN   31-7852015        NaN              NaN      NaN
# 4  7GCA (Champion)      NaN          420        NaN              NaN      NaN
#
#    ... status       built firstflightdate seatconfiguration  \
# ...

# %%
state_vectors = pd.read_csv("data/state_vectors_7to9MAY21.csv")
state_vectors.head()
# Out:
#          time  icao24        lat       lon  velocity  heading  vertrate  \
# 0  1620561059  346253  40.470978 -3.558731       NaN      NaN       NaN
# 1  1620561119  346253  40.475972 -3.554889       NaN      NaN       NaN
# 2  1620561179  346253  40.471969 -3.551846       NaN      NaN       NaN
# 3  1620561239  346253  40.480247 -3.551453       NaN      NaN       NaN
# 4  1620561299  346253  40.488007 -3.556900       NaN      NaN       NaN
#
#   callsign  onground  alert    spi  squawk  baroaltitude  geoaltitude  \
# 0   FAUNA6      True  False  False     NaN           NaN          NaN
# 1   FAUNA6      True  False  False     NaN           NaN          NaN
# 2   FAUNA6      True  False  False     NaN           NaN          NaN
# 3   FAUNA6      True  False  False     NaN           NaN          NaN
# 4   FAUNA6      True  False  False     NaN           NaN          NaN
#
#    lastposupdate   lastcontact        hour    minute      recent icao24.1
# ...
